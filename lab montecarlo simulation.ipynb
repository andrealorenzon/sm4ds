# %%
#simulazione di montecarlo

n = 40
beta0 = 10
beta1 = .5
x = runif(n,0,10)   #40 valori random tra 0 e 10
y = beta0 +beta1*x+rnorm(n,0,.25)

for (i in 1:n) {
    
} 
x
# Out:
#  [1] 1.7323662 3.7507538 3.8812182 4.4322792 8.6719889 5.0124153 0.2742391
#  [8] 7.9426764 9.0903406 5.9574021 9.3655376 6.5873909 0.4231242 3.5292258
# [15] 9.5951877 7.8669803 2.9158186 0.9073618 2.8023516 3.7523943 6.7901255
# [22] 2.1462166 8.8221696 4.0377975 3.8109155 9.1468212 0.9735907 2.2000757
# [29] 1.2820495 2.0936714 6.3304586 0.3855858 9.9606178 7.5481644 5.0487002
# [36] 7.3754659 9.8820232 3.1067953 2.5013647 7.1153513

# %%
y
# Out:
#  [1] 10.87534 11.46090 12.11194 12.04893 14.10746 12.46229 10.13656 14.04157
#  [9] 14.51642 12.79239 14.68830 13.33272 10.33250 11.84382 14.57590 13.90124
# [17] 11.45815 10.69296 11.14656 11.92448 13.59874 11.01327 14.06908 11.83519
# [25] 12.03892 14.41416 10.44979 11.13059 10.27067 11.18635 13.24047 10.26752
# [33] 15.30311 13.45463 12.55903 13.58300 15.17571 11.66377 10.98396 13.37709

# %%
plot(x,y)
# Out:
# plot without title

# %%
R = 100

for (i in 1:R) {
    y = beta0+beta1*x+rnorm(n,0,.25) #modello generatore
    plot(x,y, ylim=c(9,16), col=rgb(red=0, green=0, blue=0,alpha=.2), pch="x")
    par(new=TRUE)
    #abline(coef(lm(y~x)))
    #par(new=TRUE)
}
# Out:
# plot without title

# %%
lm(formula = y ~ x)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      10.035        0.498
